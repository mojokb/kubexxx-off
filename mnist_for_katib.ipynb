# %%
import os
import argparse
import kubeflow.katib as kc
import json
from datetime import datetime
from kubernetes.client import V1ObjectMeta

class KatibJob(object):
    def get_experiment_name(self, experiment_name):
        now = datetime.now()
        return experiment_name + "-" + now.strftime("%Y%m%d%H%m%S")
        
    def train(self):
        parser= argparse.ArgumentParser()
        parser.add_argument("--max_failed_trial_count", required=False, type=int, default=3)
        parser.add_argument("--parallel_trial_count", required=False, type=int, default=1)        
        parser.add_argument("--max_trial_count", required=False, type=int, default=12)        
        parser.add_argument("--user_namespace", required=False, type=str, default="amaramusic")                
        parser.add_argument("--train_image_name", required=False, default='kubeflow-registry.default.svc.cluster.local:30000/mnist-train:B286FA83')
        args = parser.parse_args()
        
        user_namespace = args.user_namespace
 
        #katibe description
        metadata = V1ObjectMeta(
          name = self.get_experiment_name("mnist"),
          namespace = user_namespace  
        )

        algorithm_spec = kc.V1alpha3AlgorithmSpec(
          algorithm_name = "random"
        )
        
        objective_spec = kc.V1alpha3ObjectiveSpec(
          type = "maximize",
          goal = 0.99999,
          objective_metric_name = "val_acc"
        )
        
        parameters = [
            kc.V1alpha3ParameterSpec(
              name = "--epoch",
              parameter_type = "int",
              feasible_space = kc.V1alpha3FeasibleSpace(
                 min = "10",
                 max = "30" 
              )  
            ),
            kc.V1alpha3ParameterSpec(
              name = "--batch_size",
              parameter_type = "int",
              feasible_space = kc.V1alpha3FeasibleSpace(
                 min = "8",
                 max = "24" 
              )  
            ),
            kc.V1alpha3ParameterSpec(
              name = "--dropout_rate",
              parameter_type = "double",
              feasible_space = kc.V1alpha3FeasibleSpace(
                 min = "0.1",
                 max = "0.9" 
              )  
            )        
        ]
        
        go_template = kc.V1alpha3GoTemplate(
          raw_template =   
              "apiVersion: \"batch/v1\"\n" 
            + "kind: Job\n"
            + "metadata:\n"
            + "  name: {{.Trial}}\n"
            +f"  namespace: {user_namespace}\n"
            + "spec:\n"
            + "  template:\n" 
            + "    spec:\n"
            + "      containers:\n" 
            + "      - name: {{.Trial}}\n" 
            +f"        image: {args.train_image_name}\n" 
            + "        command:\n" 
            + "        - \"python\"\n" 
            + "        - \"/app/mnist_for_train.py\"\n"
            + "        {{- with .HyperParameters}}\n"
            + "        {{- range .}}\n"
            + "        - \"{{.Name}}={{.Value}}\"\n"
            + "        {{- end}}\n"
            + "        {{- end}}\n"
            + "        resources:\n"             
            + "          limits:\n"                         
            + "            cpu: 0.5\n"                         
            + "            memory: 2Gi\n"                                     
            + "      restartPolicy: Never"
        )   
        
        trial_template= kc.V1alpha3TrialTemplate(go_template=go_template)

        
        experiment = kc.V1alpha3Experiment(
          api_version = "kubeflow.org/v1alpha3",
          kind = "Experiment",
          metadata = metadata,
          spec = kc.V1alpha3ExperimentSpec(
            max_trial_count = args.max_trial_count,
            parallel_trial_count = args.parallel_trial_count,
            max_failed_trial_count = args.max_failed_trial_count,
            algorithm = algorithm_spec,
            objective = objective_spec,
            parameters = parameters,  
            trial_template = trial_template
          )  
        )
        kclient = kc.KatibClient()
        kclient.create_experiment(experiment)

        metrics = {
          'metrics': [{
              'experiment_name': metadata.name, # The name of the metric. Visualized as the column name in the runs table.
              'format': "raw"  # The optional format of the metric. Supported values are "RAW" (displayed in raw format) and "PERCENTAGE" (displayed in percentage format).
          }]
        }
        with open('/output.txt', "w") as output_f:
          output_f.write(metadata.name) 
        
        with open('/mlpipeline-metrics.json', 'w') as metric_f: 
          json.dump(metrics, metric_f)        
        
if __name__=="__main__":
    if os.getenv('FAIRING_RUNTIME', None) is None:
        """
        from kubeflow import fairing
        from kubeflow.fairing.kubernetes import utils as k8s_utils

        DOCKER_REGISTRY = 'kubeflow-registry.default.svc.cluster.local:30000'
        fairing.config.set_builder(
            'append',
            image_name='mnist-katib-job',
            base_image='brightfly/katib-sdk:0.0.1',
            registry=DOCKER_REGISTRY,
            push=True)
        # cpu 1, memory 1GiB
        fairing.config.set_deployer('job',
                                    namespace='amaramusic'
                                    )
        fairing.config.run()        
        """
        from kubeflow.fairing.builders.append.append import AppendBuilder
        from kubeflow.fairing.preprocessors.converted_notebook import ConvertNotebookPreprocessor

        DOCKER_REGISTRY = 'kubeflow-registry.default.svc.cluster.local:30000'
        base_image='brightfly/katib-sdk:0.0.1'
        image_name='mnist-katib-job'

        builder = AppendBuilder(
            registry=DOCKER_REGISTRY,
            image_name=image_name,
            base_image=base_image,
            push=True,
            
            preprocessor=ConvertNotebookPreprocessor(
                notebook_file="mnist_for_katib.ipynb" )
            )
        builder.build()         
    else:
        sloshing = KatibJob()
        sloshing.train()
# Out:
# [W 201010 23:48:05 append:50] Building image using Append builder...
# [I 201010 23:48:05 base:105] Creating docker context: /tmp/fairing_context_60xj61eg
# [I 201010 23:48:05 converted_notebook:127] Converting mnist_for_katib.ipynb to mnist_for_katib.py
# [I 201010 23:48:05 docker_creds_:234] Loading Docker credentials for repository 'brightfly/katib-sdk:0.0.1'
# [W 201010 23:48:08 append:54] Image successfully built in 2.793563351035118s.
# [W 201010 23:48:08 append:94] Pushing image kubeflow-registry.default.svc.cluster.local:30000/mnist-katib-job:91DE0588...
# [I 201010 23:48:08 docker_creds_:234] Loading Docker credentials for repository 'kubeflow-registry.default.svc.cluster.local:30000/mnist-katib-job:91DE0588'
# [W 201010 23:48:08 append:81] Uploading kubeflow-registry.default.svc.cluster.local:30000/mnist-katib-job:91DE0588
# [I 201010 23:48:08 docker_session_:280] Layer sha256:d846ead9aa38bc0d35dd500ada5349fe42efb96c89db08b8abcb9ad949332c2a exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:66257906239d377cd700c566b27f12895ccefcd8d95eae7377f600208151d8e0 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:872efc07c3d848e0f55b7cbce9866a8dea7b76d8c1f131801934ea0d856b15c5 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:df80607e3e38dc3f117e967a36620c42f791afc9ca0568900d13d84c1e3a38bb exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:fb9676c4102241f220b864e98c53676e27c407c6ecfbb13c2cbc1fa4de8f1811 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:d83811f270d56d34a208f721f3dbf1b9242d1900ad8981fc7071339681998a31 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:069de100aaecb1299b09dab29a4eb39a2ca6a5f8c0a033b65ff0e15e9ea39a24 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:3a814c56ef47e07e1ee56228bf3144a6cba79cb453a4b5c2e480e41f230b7b5e exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:8f64ecfab6c102a62dd5d912d96113603663ad8b436701bf2dbd1aa9630882e7 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:fd781ca227d0199735cceb67afa81e2a073b5ef5867ca6e96ad46e002a03252a exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:6ac505cbabeccba798e608e1bb80ae66f497c2c856733800e1db060e3c875917 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:c2f81144f815902f9c6e6f7883068544e35924f0efe2275bc41c3d0c558f394c exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:af228bb15b867acbee0d6df28dbb42a8218948fdde64833bd021a255a99a2690 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:d0d480fe0d0ab233a90471379d9d3789d4153ad4611d101cfefdfc0c507d9356 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:8e7d3ffcd500d3ed0b2ee2449a36a44601b8e282cc6d541ab93f1189d4a2cf93 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:50f1fe304a9431ea025aa6ee5e8e45826fa62640a83e55be8bd3c227119cbcd2 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:7acbfba21e38804c20c4da292d2f99d88d317b83440fb2f3de0a620edf2b9595 exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:7fc152dfb3a6b5c9a436b49ff6cd72ed7eb5f1fd349128b50ee04c3c5c2355fb exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:5667fdb72017d1fb364744ca1abf7b6f3bbe9c98c3786f294a461c2866db69ab exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:ee671aafb583e2321880e275c94d49a49185006730e871435cd851f42d2a775d exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:485ea80d093de507a5ccd36effaf8dad03b67a1063edbd427fedfe667c9155bc exists, skipping
# [I 201010 23:48:08 docker_session_:280] Layer sha256:1c60aaf19cc4c142934f390281975f61956475c205b5895711f839a91f927779 exists, skipping
# [I 201010 23:48:08 docker_session_:284] Layer sha256:a0da0b1c99adc78542967d4d3476a466a843a2d464982b993ccf876821677c32 pushed.
# [I 201010 23:48:08 docker_session_:284] Layer sha256:41bb94845cca0ce1bd9eec6410610fd26f0d6e2b237e025b5b07735f5107d568 pushed.
# [I 201010 23:48:08 docker_session_:334] Finished upload of: kubeflow-registry.default.svc.cluster.local:30000/mnist-katib-job:91DE0588
# [W 201010 23:48:08 append:99] Pushed image kubeflow-registry.default.svc.cluster.local:30000/mnist-katib-job:91DE0588 in 0.2682405400555581s.

# %%
# !pip install kubeflow-katib==0.0.2
